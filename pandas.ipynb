# %%
import pandas as pd
df=pd.read_csv('Family Guy Dataset.csv')
df
# Out:
#      Season  No. of Episode (Season)  No. of Episode (Overall)  \
# 0         1                        1                         1
# 1         1                        2                         2
# 2         1                        3                         3
# 3         1                        4                         4
# 4         1                        5                         5
# ..      ...                      ...                       ...
# 395      21                        7                       396
# 396      21                        8                       397
# 397      21                        9                       398
# 398      21                       10                       399
# 399      21                       11                       400
#
#          Title of the Episode                 Director Assistant Director  \
# 0          Death Has a Shadow               Peter Shin                NaN
# ...
